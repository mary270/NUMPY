# %%
import cv2
import numpy as np
from PIL import Image
im_path = "/content/red.png"


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))


# Define the range of red color in BGR format
lower_red = (0, 0, 100)
upper_red = (50, 100, 255)




# Threshold the image to get a binary mask of red pixels
mask = cv2.inRange(im_array, lower_red, upper_red)


# Replace all red pixels with black pixels
im_array[mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FD9284AACD0>
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FD9284CFC70>

# %%
import cv2
import numpy as np
from PIL import Image
im_path = "/content/5230e127b607942cc05734377a092cf3.jpg"


im_array = cv2.imread(im_path)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))


# Define the range of red color in BGR format
lower_red = (0, 0, 100)
upper_red = (50, 50, 255)


# Threshold the image to get a binary mask of red pixels
mask = cv2.inRange(im_array, lower_red, upper_red)


# Replace all red pixels with black pixels
im_array[mask != 0] = (0, 0, 0)

display(Image.fromarray(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=720x960 at 0x7FD9284CFE20>
# <PIL.Image.Image image mode=RGB size=720x960 at 0x7FD9284CF070>
